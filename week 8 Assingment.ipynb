# %%
'''Training a simple deep NN on the MNIST dataset.
Gets to 98.51% test accuracy after 25 epochs
'''

from __future__ import print_function
import numpy as np
np.random.seed(1337)  # for reproducibility

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.optimizers import SGD, Adam, RMSprop,Adadelta
from keras.utils import np_utils


batch_size = 130
nb_classes = 10
nb_epoch = 25

# the data, shuffled and split between train and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

model = Sequential()
model.add(Dense(512, input_shape=(784,)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(10))
model.add(Activation('softmax'))

model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer='adadelta',#'sgd',#'adam',#'adadelta',#RMSprop(),
              metrics=['accuracy'])

history = model.fit(X_train, Y_train,
                    batch_size=batch_size, nb_epoch=nb_epoch,
                    verbose=1, validation_data=(X_test, Y_test))
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# 60000 train samples
# 10000 test samples
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# dense_19 (Dense)                 (None, 512)           401920      dense_input_7[0][0]
# ____________________________________________________________________________________________________
# activation_19 (Activation)       (None, 512)           0           dense_19[0][0]
# ____________________________________________________________________________________________________
# dropout_13 (Dropout)             (None, 512)           0           activation_19[0][0]
# ____________________________________________________________________________________________________
# dense_20 (Dense)                 (None, 512)           262656      dropout_13[0][0]
# ____________________________________________________________________________________________________
# activation_20 (Activation)       (None, 512)           0           dense_20[0][0]
# ____________________________________________________________________________________________________
# dropout_14 (Dropout)             (None, 512)           0           activation_20[0][0]
# ____________________________________________________________________________________________________
# dense_21 (Dense)                 (None, 10)            5130        dropout_14[0][0]
# ____________________________________________________________________________________________________
# activation_21 (Activation)       (None, 10)            0           dense_21[0][0]
# ====================================================================================================
# Total params: 669706
# ____________________________________________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/25
# 60000/60000 [==============================] - 24s - loss: 0.3601 - acc: 0.8946 - val_loss: 0.1548 - val_acc: 0.9527
# Epoch 2/25
# 60000/60000 [==============================] - 23s - loss: 0.1515 - acc: 0.9551 - val_loss: 0.1063 - val_acc: 0.9686
# Epoch 3/25
# 60000/60000 [==============================] - 23s - loss: 0.1089 - acc: 0.9675 - val_loss: 0.0956 - val_acc: 0.9702
# Epoch 4/25
# 60000/60000 [==============================] - 24s - loss: 0.0869 - acc: 0.9730 - val_loss: 0.0842 - val_acc: 0.9740
# Epoch 5/25
# 60000/60000 [==============================] - 24s - loss: 0.0698 - acc: 0.9789 - val_loss: 0.0706 - val_acc: 0.9788
# Epoch 6/25
# 60000/60000 [==============================] - 24s - loss: 0.0605 - acc: 0.9811 - val_loss: 0.0657 - val_acc: 0.9793
# Epoch 7/25
# 60000/60000 [==============================] - 24s - loss: 0.0516 - acc: 0.9840 - val_loss: 0.0636 - val_acc: 0.9802
# Epoch 8/25
# 60000/60000 [==============================] - 24s - loss: 0.0443 - acc: 0.9865 - val_loss: 0.0637 - val_acc: 0.9805
# Epoch 9/25
# 60000/60000 [==============================] - 24s - loss: 0.0394 - acc: 0.9879 - val_loss: 0.0645 - val_acc: 0.9809
# Epoch 10/25
# 60000/60000 [==============================] - 24s - loss: 0.0345 - acc: 0.9895 - val_loss: 0.0584 - val_acc: 0.9822
# Epoch 11/25
# 60000/60000 [==============================] - 24s - loss: 0.0315 - acc: 0.9903 - val_loss: 0.0587 - val_acc: 0.9818
# Epoch 12/25
# 60000/60000 [==============================] - 24s - loss: 0.0279 - acc: 0.9913 - val_loss: 0.0587 - val_acc: 0.9827
# Epoch 13/25
# 60000/60000 [==============================] - 24s - loss: 0.0250 - acc: 0.9924 - val_loss: 0.0578 - val_acc: 0.9824
# Epoch 14/25
# 60000/60000 [==============================] - 24s - loss: 0.0219 - acc: 0.9936 - val_loss: 0.0560 - val_acc: 0.9828
# Epoch 15/25
# 60000/60000 [==============================] - 24s - loss: 0.0207 - acc: 0.9937 - val_loss: 0.0559 - val_acc: 0.9837
# Epoch 16/25
# 60000/60000 [==============================] - 24s - loss: 0.0177 - acc: 0.9941 - val_loss: 0.0582 - val_acc: 0.9828
# Epoch 17/25
# 60000/60000 [==============================] - 24s - loss: 0.0161 - acc: 0.9951 - val_loss: 0.0587 - val_acc: 0.9842
# Epoch 18/25
# 60000/60000 [==============================] - 24s - loss: 0.0150 - acc: 0.9953 - val_loss: 0.0573 - val_acc: 0.9841
# Epoch 19/25
# 60000/60000 [==============================] - 24s - loss: 0.0133 - acc: 0.9960 - val_loss: 0.0601 - val_acc: 0.9832
# Epoch 20/25
# 60000/60000 [==============================] - 24s - loss: 0.0120 - acc: 0.9964 - val_loss: 0.0641 - val_acc: 0.9824
# Epoch 21/25
# 60000/60000 [==============================] - 24s - loss: 0.0112 - acc: 0.9967 - val_loss: 0.0605 - val_acc: 0.9832
# Epoch 22/25
# 60000/60000 [==============================] - 24s - loss: 0.0110 - acc: 0.9967 - val_loss: 0.0598 - val_acc: 0.9835
# Epoch 23/25
# 60000/60000 [==============================] - 24s - loss: 0.0101 - acc: 0.9969 - val_loss: 0.0600 - val_acc: 0.9831
# Epoch 24/25
# 60000/60000 [==============================] - 24s - loss: 0.0090 - acc: 0.9972 - val_loss: 0.0613 - val_acc: 0.9842
# Epoch 25/25
# 60000/60000 [==============================] - 24s - loss: 0.0085 - acc: 0.9977 - val_loss: 0.0600 - val_acc: 0.9851
# Test score: 0.0599679420986
# Test accuracy: 0.9851
